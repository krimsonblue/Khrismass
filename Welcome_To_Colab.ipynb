# %% [markdown]
# <a href="https://colab.research.google.com/github/krimsonblue/Khrismass/blob/master/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Welcome to Colab!

# %% [markdown]
# # Creating The Application

# %%
def addSomething(value1 , value2):
  return value1 + value2

print (addSomething(1,2))
# Out:
# 3

# %% [markdown]
# **Creating A Form Field**

# %%
name = input ("Type your name: ")
print(f"Your name is: {name}")
# Out:
# Type your name: countytv
# Your name is: countytv
